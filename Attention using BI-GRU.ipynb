# %% [markdown]
# # Lab - 8 : Attention Mechanism using BI-GRU
# ---
# - Namansh Singh Maurya
# - 22MIA1034

# %% [markdown]
# #### Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Bidirectional, GRU, Dense, Activation, Layer
import numpy as np

# %% [markdown]
# #### Loading the imdb dataset

# %%
vocab_size = 1000
max_len = 200
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words = vocab_size)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# #### Padding to make all the sentences to same length

# %%
x_train = pad_sequences(x_train,maxlen=max_len,padding='post')
x_test = pad_sequences(x_test,maxlen=max_len,padding='post')

# %% [markdown]
# #### Defining input layer

# %%
input_layer = tf.keras.layers.Input(shape=(max_len,))

# %% [markdown]
# #### Defining Embedding Layer

# %%
embedding = Embedding(input_dim=vocab_size,output_dim=128,input_length=max_len)(input_layer)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# #### Defining BI-GRU Layer

# %%
bi_gru_output = Bidirectional(GRU(64,return_sequences=True))(embedding)

# %% [markdown]
# #### Attention Mechanism

# %%
class AttentionLayer(Layer):
  def __init__(self, **kwgrs):
    super(AttentionLayer, self).__init__(**kwgrs)
    self.w = tf.keras.layers.Dense(32, activation='tanh')
    self.v = tf.keras.layers.Dense(1, activation=None)

  def call(self,bi_gru_output):
    w = self.w(bi_gru_output)
    v = self.v(w)
    attention_scores = tf.nn.softmax(v,axis=1)
    context_vector = tf.reduce_sum(attention_scores*bi_gru_output, axis=1)
    return context_vector

# %%
context_vector = AttentionLayer()(bi_gru_output)

# %%
output = Dense(1, activation='sigmoid')(context_vector)

# %%
model = tf.keras.Model(inputs = input_layer, outputs = output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### Training the Model

# %%
model.fit(x_train,y_train,batch_size=64,epochs=3,validation_data=(x_test,y_test))
# Out:
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.7055 - loss: 0.5257 - val_accuracy: 0.8596 - val_loss: 0.3235
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.8698 - loss: 0.3085 - val_accuracy: 0.8738 - val_loss: 0.2972
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.8845 - loss: 0.2733 - val_accuracy: 0.8704 - val_loss: 0.3005

# %% [markdown]
# #### Testing the model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8684 - loss: 0.3038
# Test accuracy: 0.8703600168228149
