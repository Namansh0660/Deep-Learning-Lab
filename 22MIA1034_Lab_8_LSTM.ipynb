# %% [markdown]
# # 22MIA1034 - Namansh Singh Maurya
# ## Lab_A_5a - LSTM

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv("/content/IMDB Dataset.csv")
print(df.head())
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# # Text to Tokens

# %%
# convert text to tokens
t = Tokenizer(num_words=5000)
t.fit_on_texts(df['review'])
x = t.texts_to_sequences(df['review'])
max_length = 100
xp = pad_sequences(x, maxlen=max_length, padding="post")
y = np.array(df['sentiment'].map({'positive':1, 'negative':0}))

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(xp, y, random_state=42, test_size=0.2)

# %% [markdown]
# # Model Training

# %%
model = Sequential([
    Embedding(input_dim = 5000, output_dim = 32, input_length = max_length),
    LSTM(16, activation = 'relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.6469 - loss: 10.2030 - val_accuracy: 0.6983 - val_loss: 0.6167
# Epoch 2/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.7195 - loss: 0.5971 - val_accuracy: 0.7041 - val_loss: 0.5727
# Epoch 3/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.7406 - loss: 0.5525 - val_accuracy: 0.7182 - val_loss: 0.5533
# Epoch 4/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - accuracy: 0.7532 - loss: 0.5226 - val_accuracy: 0.7288 - val_loss: 0.5362
# Epoch 5/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.7702 - loss: 0.4758 - val_accuracy: 0.7383 - val_loss: 0.5217

# %% [markdown]
# # Printing Loss and Accuracy

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7360 - loss: 0.5254
# Loss: 0.5216873288154602, Accuracy: 0.7383000254631042

# %% [markdown]
# # Prediction

# %%
st = ["This is an amazing movie"]
ss = t.texts_to_sequences(st)
ssq = pad_sequences(ss, maxlen=max_length, padding="post")
p = model.predict(ssq)
print("Predicted Sentiment : ", "Positive" if p[0][0]>0.5 else "Negative")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Predicted Sentiment :  Positive
